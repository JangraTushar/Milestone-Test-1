# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("lungs_cancer.csv")

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df_c = df.copy()

# %%
df_c['LUNG_CANCER'] = df_c['LUNG_CANCER'].map({"YES" : 1,"NO" : 0})

# %%
df_c['LUNG_CANCER']
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 2995    0
# 2996    0
# 2997    1
# 2998    1
# 2999    1
# Name: LUNG_CANCER, Length: 2998, dtype: int64

# %%
df_f = df[df['GENDER']== "F"]

# %%
df_c.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
for i in ['SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
       'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN',]:
       df_c[i] = df_c[i].map({2:1,1:0})

# %%
df_c
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        0               0        0              1
# 1         F   55        0               1        1              0
# 2         F   78        1               1        0              0
# 3         M   60        1               0        0              0
# 4         F   80        0               0        1              0
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        1               0        0              1
# 2996      F   75        0               1        0              0
# 2997      F   62        1               1        1              0
# 2998      M   30        0               0        1              1
# 2999      M   40        0               1        1              0
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   1        0        1         1                  1
# ...

# %%
df_f = df_c[df_c['GENDER']== "F"]

# %%
df_f
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 1         F   55        0               1        1              0
# 2         F   78        1               1        0              0
# 4         F   80        0               0        1              0
# 5         F   58        0               0        0              1
# 6         F   70        0               0        0              1
# ...     ...  ...      ...             ...      ...            ...
# 2993      F   80        1               0        0              0
# 2994      F   45        0               1        0              1
# 2995      F   71        1               0        0              1
# 2996      F   75        0               1        0              0
# 2997      F   62        1               1        1              0
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 1                   0        1        1         1                  0
# ...

# %%
df_c[df_c['SMOKING']==1].groupby('GENDER')['ANXIETY'].sum()
# Out:
# GENDER
# F    354
# M    332
# Name: ANXIETY, dtype: int64

# %%
df_f.groupby("ANXIETY")['SMOKING'].sum()
# Out:
# ANXIETY
# 0    397
# 1    354
# Name: SMOKING, dtype: int64

# %% [markdown]
# There are 354 females out of 1486 who do smoking and have anxiety
# There are 397 females who are smoking but don't have anxiety issue

# %%
df_f[df_f['SMOKING'] == 0]["ANXIETY"].value_counts()
# Out:
# ANXIETY
# 1    398
# 0    337
# Name: count, dtype: int64

# %% [markdown]
# There are 398 females out of 1486 who have anxiety but they rae not smoker

# %%
df_m = df_c[df_c['GENDER']== "M"]

# %%
df_m
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        0               0        0              1
# 3         M   60        1               0        0              0
# 8         M   77        0               1        0              1
# 12        M   79        0               0        0              1
# 13        M   70        0               1        1              1
# ...     ...  ...      ...             ...      ...            ...
# 2984      M   63        1               0        0              0
# 2986      M   55        1               0        0              1
# 2988      M   53        1               0        1              0
# 2998      M   30        0               0        1              1
# 2999      M   40        0               1        1              0
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   1        0        1         1                  1
# ...

# %%
df_m[df_m['SMOKING'] == 0]["ANXIETY"].value_counts()
# Out:
# ANXIETY
# 1    397
# 0    393
# Name: count, dtype: int64

# %%
df_m[df_m['SMOKING'] == 1]["ANXIETY"].value_counts()
# Out:
# ANXIETY
# 0    390
# 1    332
# Name: count, dtype: int64

# %% [markdown]
# There are 322 males out of 1512 who have anxiety and they are also smoker
# There are 397 males out of 1512 who have anxiety but thay are not smoker
# There are 390 males out of 1512 who have anxiety anf they are smoker

# %%
df_c['GENDER'].value_counts()
# Out:
# GENDER
# M    1512
# F    1486
# Name: count, dtype: int64

# %% [markdown]
# Both gender have equally contribution in this survey there is slight difference in between gender count

# %%
df_c[df_c['SMOKING']==1]['GENDER'].value_counts()
# Out:
# GENDER
# F    751
# M    722
# Name: count, dtype: int64

# %%
for i in ['YELLOW_FINGERS',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
        'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER']:
    result = df_m[df_m['SMOKING'] == 1][i].value_counts()
    print(result)
# Out:
# YELLOW_FINGERS
# 1    372
# 0    350
# Name: count, dtype: int64
# PEER_PRESSURE
# 0    368
# 1    354
# Name: count, dtype: int64
# CHRONIC_DISEASE
# 1    385
# 0    337
# Name: count, dtype: int64
# FATIGUE
# 0    367
# 1    355
# Name: count, dtype: int64
# ALLERGY
# 1    373
# 0    349
# Name: count, dtype: int64
# WHEEZING
# 0    375
# 1    347
# Name: count, dtype: int64
# COUGHING
# 1    374
# 0    348
# Name: count, dtype: int64
# SHORTNESS_OF_BREATH
# 0    371
# 1    351
# Name: count, dtype: int64
# SWALLOWING_DIFFICULTY
# 0    364
# 1    358
# Name: count, dtype: int64
# CHEST_PAIN
# 0    384
# 1    338
# Name: count, dtype: int64
# LUNG_CANCER
# 1    367
# 0    355
# Name: count, dtype: int64

# %% [markdown]
# results about those males who are smoker and have issues or not

# %%
plot.pie(y = df['Category'] , figsize = (12,12) , autopct='%1.3f%%')df_copy['Category'].value_counts()

# %%
for i in ['YELLOW_FINGERS',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
        'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER']:
    result = df_m[df_m['SMOKING'] == 0][i].value_counts()
    print(result)
# Out:
# YELLOW_FINGERS
# 1    416
# 0    374
# Name: count, dtype: int64
# PEER_PRESSURE
# 1    407
# 0    383
# Name: count, dtype: int64
# CHRONIC_DISEASE
# 0    398
# 1    392
# Name: count, dtype: int64
# FATIGUE
# 0    403
# 1    387
# Name: count, dtype: int64
# ALLERGY
# 1    404
# 0    386
# Name: count, dtype: int64
# WHEEZING
# 1    398
# 0    392
# Name: count, dtype: int64
# COUGHING
# 0    397
# 1    393
# Name: count, dtype: int64
# SHORTNESS_OF_BREATH
# 1    395
# 0    395
# Name: count, dtype: int64
# SWALLOWING_DIFFICULTY
# 0    419
# 1    371
# Name: count, dtype: int64
# CHEST_PAIN
# 1    414
# 0    376
# Name: count, dtype: int64
# LUNG_CANCER
# 0    404
# 1    386
# Name: count, dtype: int64

# %% [markdown]
# the above result is of those males who are not smoker but have issues

# %%
for i in ['YELLOW_FINGERS',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
        'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER']:
    result = df_f[df_f['SMOKING'] == 1][i].value_counts()
    print(result)
# Out:
# YELLOW_FINGERS
# 1    384
# 0    367
# Name: count, dtype: int64
# PEER_PRESSURE
# 0    394
# 1    357
# Name: count, dtype: int64
# CHRONIC_DISEASE
# 1    400
# 0    351
# Name: count, dtype: int64
# FATIGUE
# 1    381
# 0    370
# Name: count, dtype: int64
# ALLERGY
# 1    377
# 0    374
# Name: count, dtype: int64
# WHEEZING
# 1    386
# 0    365
# Name: count, dtype: int64
# COUGHING
# 1    387
# 0    364
# Name: count, dtype: int64
# SHORTNESS_OF_BREATH
# 0    395
# 1    356
# Name: count, dtype: int64
# SWALLOWING_DIFFICULTY
# 0    389
# 1    362
# Name: count, dtype: int64
# CHEST_PAIN
# 0    378
# 1    373
# Name: count, dtype: int64
# LUNG_CANCER
# 1    389
# 0    362
# Name: count, dtype: int64

# %% [markdown]
# the above result are for womens who are smoker and have following issues or not

# %%
for i in ['YELLOW_FINGERS',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
        'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER']:
    result = df_f[df_f['SMOKING'] == 0][i].value_counts()
    print(result)
# Out:
# YELLOW_FINGERS
# 1    369
# 0    366
# Name: count, dtype: int64
# PEER_PRESSURE
# 1    377
# 0    358
# Name: count, dtype: int64
# CHRONIC_DISEASE
# 0    384
# 1    351
# Name: count, dtype: int64
# FATIGUE
# 0    390
# 1    345
# Name: count, dtype: int64
# ALLERGY
# 0    369
# 1    366
# Name: count, dtype: int64
# WHEEZING
# 0    375
# 1    360
# Name: count, dtype: int64
# COUGHING
# 1    376
# 0    359
# Name: count, dtype: int64
# SHORTNESS_OF_BREATH
# 0    375
# 1    360
# Name: count, dtype: int64
# SWALLOWING_DIFFICULTY
# 1    378
# 0    357
# Name: count, dtype: int64
# CHEST_PAIN
# 1    369
# 0    366
# Name: count, dtype: int64
# LUNG_CANCER
# 1    375
# 0    360
# Name: count, dtype: int64

# %% [markdown]
# the above result are for those womens who are not smoker but have following issues or not

# %%
sns.countplot(x = "SMOKING", hue="LUNG_CANCER" , data=df_c , palette="viridis")
# Out:
# <Axes: xlabel='SMOKING', ylabel='count'>

# %%
sns.countplot(data = df_c , x = "YELLOW_FINGERS" , hue="SMOKING" , palette="viridis")
# Out:
# <Axes: xlabel='YELLOW_FINGERS', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['AGE'],kde=True,bins=20)
plt.title("Age Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# the age graph is also symmetric

# %% [markdown]
# There is no outlier in this data

# %%
num_col = df_c[['AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
       'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
       'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
       'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER']]

# %%
num_col
# Out:
#       AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC_DISEASE  \
# 0      65        0               0        0              1                1
# 1      55        0               1        1              0                0
# 2      78        1               1        0              0                0
# 3      60        1               0        0              0                1
# 4      80        0               0        1              0                0
# ...   ...      ...             ...      ...            ...              ...
# 2995   71        1               0        0              1                1
# 2996   75        0               1        0              0                0
# 2997   62        1               1        1              0                1
# 2998   30        0               0        1              1                1
# 2999   40        0               1        1              0                0
#
# ...

# %%
correlaiton =num_col.corr()
plt.figure(figsize=(10,8))
sns.heatmap(correlaiton,annot=True,fmt='.2f',cmap='RdBu',linewidths=0.5)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df_c[['AGE','SMOKING','CHEST_PAIN']])
plt.show()

# %%
for col in num_col:
    plt.figure(figsize=(12, 8)) 
    sns.countplot(x=col, data=df_c, palette="viridis")  
    plt.xticks(rotation=90)
    plt.title(f"Count Plot of {col}", fontsize=16, fontweight='bold')
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.show()
